# %% [markdown]
# # Q1

# %%
# 1.
import pandas as pd

data_dict = {
    'name': ['Tom', 'Jerry', 'Mike'],
    'score': [85, 92, 78],
    'gender': ['男', '女', '男']
}

df_obj = pd.DataFrame(data_dict)
df_obj
# Out:
#     name  score gender
# 0    Tom     85      男
# 1  Jerry     92      女
# 2   Mike     78      男

# %%
# 2.
df_obj.head(1)
# Out:
#   name  score gender
# 0  Tom     85      男

# %%
df_obj.shape
# Out:
# (3, 3)

# %%
df_obj.columns
# Out:
# Index(['name', 'score', 'gender'], dtype='object')

# %%
df_obj.dtypes
# Out:
# name      object
# score      int64
# gender    object
# dtype: object

# %%
# 3.
data_list = [[1,"A"],[2,"B"],[3,"C"]]
df_list = pd.DataFrame(data_list,columns = ['id','tag'])
df_list
# Out:
#    id tag
# 0   1   A
# 1   2   B
# 2   3   C

# %% [markdown]
# # Q2

# %%
# 1.
df_obj[['score','gender']]
# Out:
#    score gender
# 0     85      男
# 1     92      女
# 2     78      男

# %%
# 2.
df_obj.loc[[0,2]]
# Out:
#    name  score gender
# 0   Tom     85      男
# 2  Mike     78      男

# %%
# 3. 
df_obj[df_obj['score'] > 80]
# Out:
#     name  score gender
# 0    Tom     85      男
# 1  Jerry     92      女

# %%
# 4.
df_obj['grade'] = "良好"   #新建一列，里面的值均为良好
df_obj.loc[df_obj['score']>=90,'grade']= '优秀'
df_obj
# Out:
#     name  score gender grade
# 0    Tom     85      男    良好
# 1  Jerry     92      女    优秀
# 2   Mike     78      男    良好

# %%
# 5.
df_obj.drop('gender',axis = 1,inplace = True)
df_obj
# Out:
#     name  score grade
# 0    Tom     85    良好
# 1  Jerry     92    优秀
# 2   Mike     78    良好

# %% [markdown]
# # Q3

# %%
# 1.
data = {"x":[1,None,3],"y":[None,5,6]}
df_obj = pd.DataFrame(data)
df_obj
# Out:
#      x    y
# 0  1.0  NaN
# 1  NaN  5.0
# 2  3.0  6.0

# %%
df_obj.isnull()  #检测缺失值
df_obj.isnull().sum() #统计每列缺失数量
# Out:
# x    1
# y    1
# dtype: int64

# %%
# 2.
df_obj.fillna(0)
# Out:
#      x    y
# 0  1.0  0.0
# 1  0.0  5.0
# 2  3.0  6.0

# %%
df_obj.dropna()
# Out:
#      x    y
# 2  3.0  6.0

# %% [markdown]
# # Q4

# %%
df_obj = pd.DataFrame({
    'name': ['Tom', 'Jerry', 'Mike'],
    'score': [85, 92, 78],
    'gender': ['男', '女', '男']
})
df_obj
# Out:
#     name  score gender
# 0    Tom     85      男
# 1  Jerry     92      女
# 2   Mike     78      男

# %%
# 1.
df_obj.groupby('gender')['score'].agg(['mean','max'])
# Out:
#         mean  max
# gender
# 女       92.0   92
# 男       81.5   85

# %%
# 2.
df_obj.groupby('gender').size()
# Out:
# gender
# 女    1
# 男    2
# dtype: int64

# %% [markdown]
# # Q5

# %%
# 1.
df_obj.sort_values('score',ascending = True)
# Out:
#     name  score gender
# 2   Mike     78      男
# 0    Tom     85      男
# 1  Jerry     92      女

# %%
# 2.
df_obj.loc[3] = ['Tom',85,'男']
df_obj
# Out:
#     name  score gender
# 0    Tom     85      男
# 1  Jerry     92      女
# 2   Mike     78      男
# 3    Tom     85      男

# %%
# ?pd.DataFrame.drop_duplicates
# Out:
# Signature:
# pd.DataFrame.drop_duplicates(
#     self,
#     subset: 'Hashable | Sequence[Hashable] | None' = None,
#     *,
#     keep: 'DropKeep' = 'first',
#     inplace: 'bool' = False,
#     ignore_index: 'bool' = False,
# ) -> 'DataFrame | None'
# Docstring:
# Return DataFrame with duplicate rows removed.
#
# Considering certain columns is optional. Indexes, including time indexes
# are ignored.
#
# Parameters
# ----------
# subset : column label or sequence of labels, optional
#     Only consider certain columns for identifying duplicates, by
#     default use all of the columns.
# keep : {'first', 'last', ``False``}, default 'first'
#     Determines which duplicates (if any) to keep.
#
#     - 'first' : Drop duplicates except for the first occurrence.
#     - 'last' : Drop duplicates except for the last occurrence.
#     - ``False`` : Drop all duplicates.
#
# inplace : bool, default ``False``
#     Whether to modify the DataFrame rather than creating a new one.
# ...

# %%
# 去重
df_obj.drop_duplicates(keep = 'first')
# Out:
#     name  score gender  score_std
# 0    Tom     85      男   0.000000
# 1  Jerry     92      女   1.224745
# 2   Mike     78      男  -1.224745

# %% [markdown]
# # Q6

# %%
# 1.
df1 = pd.DataFrame ({"id":[1,2], "name":["X","Y"]})
df2 = pd.DataFrame ({"id":[1,2], "age":[20,30]})
pd.merge(df1,df2,on = 'id')
# Out:
#    id name  age
# 0   1    X   20
# 1   2    Y   30

# %%
# 2.
df_a = pd.DataFrame ({"val":[1,2]})
df_b = pd.DataFrame ({"val":[3,4]})
pd.concat([df_a,df_b],ignore_index = True)
# Out:
#    val
# 0    1
# 1    2
# 2    3
# 3    4

# %% [markdown]
# # Q7

# %%
# 1.
date_list = ["2025-01-01","2025-01-02","2025-01-03"]
date_a = pd.to_datetime(date_list)
date_a
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03'], dtype='datetime64[ns]', freq=None)

# %%
# 2.
date_a.month #月份
# Out:
# Index([1, 1, 1], dtype='int32')

# %%
date_a.day_name()  #星期
# Out:
# Index(['Wednesday', 'Thursday', 'Friday'], dtype='object')

# %% [markdown]
# # Q8

# %%
# 1.
df_obj['score_std'] = (df_obj['score']- df_obj['score'].mean()) / df_obj['score'].std()
df_obj
# Out:
#     name  score gender  score_std
# 0    Tom     85      男   0.000000
# 1  Jerry     92      女   1.224745
# 2   Mike     78      男  -1.224745
# 3    Tom     85      男   0.000000

# %%
# 2.
pd.pivot_table(df_obj,index = 'gender',values = 'score',aggfunc = 'median')
# Out:
#         score
# gender
# 女        92.0
# 男        85.0
